# %%
import numpy as np
import matplotlib.pyplot as plt

# Given Data
L_sun = 3.846e26  # Luminosity of the Sun in watts
AU = 1.496e11  # 1 Astronomical Unit in meters

# Define distances in AU
planets = ["Mercury", "Venus", "Earth", "Mars", "Jupiter", "Saturn", "Uranus", "Neptune"]
distances_AU = [0.39, 0.72, 1, 1.52, 5.2, 9.5, 19, 30]  # Distances in AU
distances_m = np.array(distances_AU) * AU  # Convert to meters

# Compute Solar Constant for each planet
solar_constants = L_sun / (4 * np.pi * distances_m**2)

# Plot the graph
plt.figure(figsize=(10, 5))
plt.plot(distances_AU, solar_constants, marker='o', linestyle='-', color='blue', label="Solar Constant")
plt.xlabel("Distance from Sun (AU)")
plt.ylabel("Solar Constant (W/m²)")
plt.title("Solar Constant vs. Distance from the Sun")
plt.grid(True)


plt.legend()
plt.show()
